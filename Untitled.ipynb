# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
from pprint import pprint

# %%
data_file = os.path.join("resources", "Updated Applicant Forms 2020 YTD.csv")
demog_df = pd.read_csv(data_file, thousands=',')
demog_df.head(10)
# Out:
#   Number of Service-wide Forms Fiscal Year To- Date\r\nBy Quarter and Form Status\r\nFiscal Year 2020  \
# 0                                                NaN
# 1                                                NaN
# 2                              Category and Form No.
# 3                                  TOTAL - ALL FORMS
# 4                                       Family Based
# 5                                             I-129F
# 6                                              I-130
# 7                                              I-485
# 8                                              I-600
# 9                                             I-601A
#
#    Column2  Column3  Column4  \
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# 2      NaN      NaN      NaN
# 3      NaN      NaN      NaN
# 4      NaN      NaN      NaN
# 5      NaN      NaN      NaN
# 6      NaN      NaN      NaN
# 7      NaN      NaN      NaN
# 8      1.0      NaN      NaN
# ...

# %%
demog_df.rename(columns = { demog_df.columns[0]: "Form Number" }, inplace = True) 
demog_df.head()
# Out:
#              Form Number  Column2  Column3  Column4      Column5  \
# 0                    NaN      NaN      NaN      NaN          NaN
# 1                    NaN      NaN      NaN      NaN          NaN
# 2  Category and Form No.      NaN      NaN      NaN  Description
# 3      TOTAL - ALL FORMS      NaN      NaN      NaN          NaN
# 4           Family Based      NaN      NaN      NaN          NaN
#
#              Column6    Column7  Column8                     Column9  \
# 0                NaN        NaN      NaN  Forms by Status and Period
# 1                NaN        NaN      NaN                 1st Quarter
# 2  Forms\r\nReceived   Approved   Denied                     Pending
# 3          1,926,497  1,643,922  256,151                   5,759,297
# 4          1,926,497  1,643,922  256,151                   5,759,297
#
#             Column10  ...           Column14   Column15 Column16   Column17  \
# 0                NaN  ...                NaN        NaN      NaN        NaN
# ...

# %%
#col = demog_df["Form Number", "Column5"]
#description_dataframe = pd.DataFrame(columns=col)
description_dataframe = demog_df[["Form Number", "Column5"]]
description_dataframe.head(10)
# Out:
#              Form Number                                            Column5
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2  Category and Form No.                                        Description
# 3      TOTAL - ALL FORMS                                                NaN
# 4           Family Based                                                NaN
# 5                 I-129F                       Petition for Alien Fiancé(e)
# 6                  I-130                        Petition for Alien Relative
# 7                  I-485  Application to Register Permanent Residence or...
# 8                  I-600  Petition to Classify Orphan as an Immediate Re...
# 9                 I-601A  Application for Provisional Unlawful Presence ...

# %%
description_dataframe.loc[:,1:2] = description_dataframe.loc[:,1:2].astype('str')
description_dataframe.dropna(how = "any")
description_dataframe.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37280/4196355551.py in <module>
# ----> 1 description_dataframe.loc[:,1:2] = description_dataframe.loc[:,1:2].astype('str')
#       2 description_dataframe.dropna(how = "any")
#       3 description_dataframe.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
# ...
